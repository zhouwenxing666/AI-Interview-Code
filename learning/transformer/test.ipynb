# %% [markdown]
# ## 实现mha

# %%
import torch
import torch.nn as nn
import math

# %%
# 正数x 求算数平方根 1e-5

# def getsqrt(num:float):
    
#     ## 拿到与num最接近的整数
#     int_num = int(num) + 1

#     mid = num / 2   


#     answer = float('inf')

#     for i in range(0,num):
#         tmp = i * i
#         if tmp - num < 1e-5 or num - tmp < 1e-5:
#             answer = tmp

#     return answer

def get_sqrt_two(num:float):

    nums = num
    # [0, num]
    # left = 0, right = num
    # mid = nums / 2
    mid = num
    while mid <= 0 or mid >= num:
        mid = num / 2

        tmp = mid * mid
        if abs(mid * mid - num) <= 1e-5:
            return mid
        elif tmp > num:
            mid = mid + 1
        else:
            mid = mid - 1
    
    return mid

print(get_sqrt_two(16))
# Out:
# 9.0
# Bad pipe message: %s [b'ragma: no']
# Bad pipe message: %s [b'ache\r\nProxy-Connection: keep-alive\r\nAccept: ', b'*\r\nUser-Agent: V2rayU/4.2.5 CFNetwork/156', b'300.101 Darwin/24.2.0\r\nAccept-Language: zh-CN,zh-Hans;q']
# Bad pipe message: %s [b'.9\r\nAccept-Encoding: gzip, deflate\r\nConnection: keep-alive\r\n']
